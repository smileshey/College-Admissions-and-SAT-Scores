# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The ongoing usefulness of the SAT and ACT standardized tests as a predictor of college success is a matter of ongoing debate. The purpose of this analysis is to investigate the results of standardized testing and evaluate the relationship between collegiate standardized testing as part of a comprehensive college admissions process.
#
# The findings from this analysis will provide insight into the validity of the SAT and ACT exams as a tool for college admissions and will inform the ongoing debate about their usage in the admissions process.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# ### Additional Background Information
#
# In recent years, the trend of colleges requiring standardized test scores such as the SAT and ACT has shifted towards becoming less strict. In Fall 2021, only 54% of colleges in the US required the SAT and 57% required the ACT.[10] The "test optional" approach has become the new normal in college admissions [9], allowing students to apply without having to submit their test scores. There is a growing list of colleges that no longer require all SAT scores [8], giving students more flexibility in the college application process.
#
# This information was not discussed at length within this analysis, however it should be used to guide the discuss pertaining to the trend within the industry regarding the usage of these tests.

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# ### Summary of Data to be Evaluated
#
# Two datasets were selected to be evaluated as part of this analysis:
#
# 1) SAT data by State (sat_2019.csv)
#
# This dataset provides information regarding SAT scores and participation by US State. The SAT scores are broken into three components:
# * The EBRW (Evidence-Based Reading and Writing) Score
# * The Math Score
# * Total Score, which is a product of EBRW and Math
#
# The participation component of the data indicates what percentage of college applicants participated in the SAT test
#
# 2) SAT and ACT data by College (sat_act_by_college.csv)
#
# This dataset contains SAT and ACT data for each college. This includes information regarding interquartile scores, the admissions rate, and total applicants per school.

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# <p><strong><span style="font-size:20px">References:</span></strong></p>
# <ol>
#   <li><a href="https://www.gcsu.edu/admissions/satact-test-information-admissions">Georgia College</a></li>
#   <li><a href="https://git.Generalassemb.ly/dsi-123/project-1">DSI Project 1</a></li>
#   <li><a href="https://www.collegeboard.org/">College Board</a></li>
#   <li><a href="https://www.nacacnet.org/">National Association for College Admissions Counseling (NACAC)</a></li>
#   <li><a href="https://www.princetonreview.com/">The Princeton Review</a></li>
#   <li><a href="https://www.ets.org/">The Educational Testing Service (ETS)</a></li>
#   <li><a href="http://www.fairtest.org/">The National Center for Fair & Open Testing (FairTest)</a></li>
#   <li><a href="https://blog.prepscholar.com/colleges-requiring-all-sat-scores-complete-list">Prepscholar. (n.d.). Colleges Requiring All SAT Scores: Complete List. [Blog post]. </a></li>
#   <li><a href="https://thehill.com/changing-america/enrichment/education/3758713-in-college-admissions-test-optional-is-the-new-normal/">The Hill. (n.d.). In College Admissions, Test Optional is the New Normal. [News article].</a></li>
#   <li><a href="https://www.collegeraptor.com/getting-in/articles/act-sat/act-vs-sat-which-college-entrance-exam-is-more-popular/#:~:text=In%20Fall%202021%2C%20though%2054,ACT%20according%20to%20College%20Navigator">College Raptor. (2021). ACT vs SAT: Which College Entrance Exam is More Popular? [Online].</a></li>
#   <li><a href="https://stackoverflow.com/questions/33476401/color-matplotlib-bar-chart-based-on-value">Stack Overflow. (n.d.). Color matplotlib bar chart based on value. [Online].</a></li>
#   <li><a href="https://www.python-graph-gallery.com/3-control-color-of-barplots">Python Graph Gallery. (n.d.). Control color of barplots. [Online].</a></li>
#   <li><a href="https://www.pythoninformer.com/python-libraries/matplotlib/data-colouring-barcharts/">Python Informer. (n.d.). Data Colouring Barcharts. [Online].</a></li>
# </ol>

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
#nums = [1,2,3,4,10]
def mean(nums):
    n = len(nums)
    return (sum(nums)/n)
#mean([1,2,3,4,10])

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def st_dev(df, col_name):
    n = len(df)
    mean = df[col_name].mean()
    variance = ((df[col_name] - mean)**2).sum()/n
    return (variance**.5)            
#st_dev([1,2,3,4,10])

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def percent_as_dec(string):
    if isinstance(string, str):
        if string == "-":
            return 0
        else:
            per = int(string.replace("%",""))
            return per/100
    else:
        return string

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports (libraries)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import os
import seaborn as sns

# data imports
state_sat = pd.read_csv('../data/sat_2019.csv')
college_sat =pd.read_csv('../data/sat_act_by_college.csv')

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
#1a: Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
college_sat.head()
# Out:
#                  School Test Optional? Applies to Class Year(s)  \
# 0   Stanford University            Yes                     2021
# 1       Harvard College            Yes                     2021
# 2  Princeton University            Yes                     2021
# 3   Columbia University            Yes                     2021
# 4       Yale University            Yes                     2021
#
#                                       Policy Details  Number of Applicants  \
# 0  Stanford has adopted a one-year test optional ...                 47452
# 1  Harvard has adopted a one-year test optional p...                 42749
# 2  Princeton has adopted a one-year test optional...                 35370
# 3  Columbia has adopted a one-year test optional ...                 40203
# 4  Yale has adopted a one-year test optional poli...                 36844
#
#   Accept Rate SAT Total 25th-75th Percentile ACT Total 25th-75th Percentile
# ...

# %%
#1b: 
state_sat.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
#2: Data Import & Cleaning

#2a: State_Sat dataset (SAT scores by state)

# Cleaning: Setting max and min for test scores
state_sat = state_sat.assign(
    Total = lambda i: i['Total'].clip(400,1600),
    EBRW = lambda i: i['EBRW'].clip(200,800),
    Math = lambda i: i['Math'].clip(200,800)
)

state_sat.columns = ['state', 'participation_rate','read_write','math','total']

states_drop = ['Virgin Islands', 'Puerto Rico', 'District of Columbia']
state_sat.drop(state_sat[state_sat['state'].isin(states_drop)].index, inplace = True)

state_sat['participation_rate'] = state_sat['participation_rate'].apply(percent_as_dec)
data = state_sat.drop(columns=['state'])

# %%
#2b: College_Sat dataset (SAT and ACT scores by College)

#--------- Cleaning

# binary-izing responses to be of type Yes/No, All/None
college_sat.loc[:, 'Applies to Class Year(s)'] = college_sat['Applies to Class Year(s)'].replace({'': 'All', 'All / Permanent Policy':'All'},'All')

# Removing two columns 
college_sat = college_sat.drop('Applies to Class Year(s)', axis = 1)
college_sat = college_sat.drop('Policy Details', axis = 1)

#Seperating out 25th and 75th percentile SAT and ACT scores

# Seperating out 25th and 75th percentile
college_sat['25th_percentile_sat'] = pd.Series([float('nan')] * len(college_sat), index= college_sat.index)
college_sat['75th_percentile_sat'] = pd.Series([float('nan')] * len(college_sat), index= college_sat.index)
college_sat['25th_percentile_act'] = pd.Series([float('nan')] * len(college_sat), index= college_sat.index)
college_sat['75th_percentile_act'] = pd.Series([float('nan')] * len(college_sat), index= college_sat.index)

# Removing rows that contain a null value in the SAT or ACT columns

college_sat = college_sat[~college_sat['SAT Total 25th-75th Percentile'].str.contains("--")]
college_sat = college_sat[~college_sat['ACT Total 25th-75th Percentile'].str.contains("--")]

#Splitting 25th and 75th percentiles from the ranges provided

#SAT
college_sat['25th_percentile_sat'] = pd.to_numeric(college_sat['SAT Total 25th-75th Percentile'].str.split("-").str[0], errors='coerce')
college_sat['75th_percentile_sat'] = pd.to_numeric(college_sat['SAT Total 25th-75th Percentile'].str.split("-").str[1], errors='coerce')
#ACT
college_sat['25th_percentile_act'] = pd.to_numeric(college_sat['ACT Total 25th-75th Percentile'].str.split("-").str[0], errors='coerce')
college_sat['75th_percentile_act'] = pd.to_numeric(college_sat['ACT Total 25th-75th Percentile'].str.split("-").str[1], errors='coerce')

# Cleaning 'Test Required?'' Column (Some values in column have an asterisk or qualification attached to their Yes answer)
college_sat = college_sat[(college_sat['Test Optional?'] == 'Yes') | (college_sat['Test Optional?'] == 'No')]

#Converting % to decimal
college_sat['Accept Rate'] = pd.to_numeric(college_sat['Accept Rate'].str.strip('%'), errors='coerce')
college_sat['Accept Rate'] = college_sat['Accept Rate'].apply(percent_as_dec)/100

#Renaming columns to lowercase
college_sat.columns=['school', 'test_optional', 'num_applicants',
        'accept_rate', 'sat_total_interquart',
       'act_total_interquart', 'sat_total_25','sat_total_75', 'act_total_25','act_total_75']

# %% [markdown]
# # Data Dictionary
#
# The two datasets selected for this project are:
#
# * sat_2019.csv: 2019 SAT Scores in the United States by State
# * sat_act_by_college.csv: SAT and ACT Scores by College
#
# ### 2019 SAT Scores in the United States by State
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|sat_2019.csv|list of US States|
# |participation_rate |float64|sat_2019.csv|Student's participation rate in the SAT by state|
# |read_write|int64|sat_2019.csv|The score attributed to the reading and writing component of the SAT|
# |math |int64|sat_2019.csv|The score attributed to the math component of the SAT|
# |total |int64|sat_2019.csv|The combined score of the reading/writing and math components of the SAT|
#
#
# ### SAT and ACT Scores by College
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |school|object|sat_act_by_college.csv|list of US colleges|
# |test_optional|object|sat_act_by_college.csv|Whether the test is required as part of the college's admissions|
# |num_applicants|int64|sat_act_by_college.csv|Number of applicants that applied to the specific college|
# |accept_rate|float64|sat_act_by_college.csv|The rate at which students are accepted to the colleg |
# |sat_total_interquart|object|sat_act_by_college.csv|The interquartile total SAT score (25th-75th percentile)|
# |act_total_interquart|object|sat_act_by_college.csv|The interquartile total ACT score (25th-75th percentile)|
# |sat_total_25|float64|sat_act_by_college.csv|The lower bound of the interquartile total SAT score (25th percentile)|
# |sat_total_75 |int64|sat_act_by_college.csv|The upper bound of the interquartile total SAT score (75th percentile)|
# |act_total_25 |float64|sat_act_by_college.csv|The lower bound of the interquartile total ACT score (25th percentile)|
# |act_total_75|float64|sat_act_by_college.csv|The upper bound of the interquartile total SAT score (75th percentile)|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#1: Summary Statistics

#1a: Summary Statistics for State_Sat dataset (SAT scores by state)
state_summary = data.describe().round(2)
display(data.describe().round(2))
# Out:
#        participation_rate  read_write    math    total
# count               50.00       50.00   50.00    50.00
# mean                 0.48      562.12  553.64  1115.84
# std                  0.39       45.74   50.75    96.14
# min                  0.02      483.00  460.00   943.00
# 25%                  0.05      529.50  516.75  1049.00
# 50%                  0.52      552.00  546.00  1098.50
# 75%                  0.82      613.00  600.50  1215.00
# max                  1.00      636.00  648.00  1284.00

# %%
#1b: Summary Statistics for College_Sat dataset (SAT and ACT scores by College)
college_summary =round(college_sat.describe(),2)
display(college_summary)
# Out:
#        num_applicants  accept_rate  sat_total_25  sat_total_75  act_total_25  \
# count           367.0       367.00        364.00        367.00        367.00
# mean          16509.4         0.55       1175.77       1368.84         25.13
# std           16481.0         0.24        123.38        107.02          3.94
# min             211.0         0.04        793.00       1050.00         15.00
# 25%            4899.0         0.36       1080.00       1290.00         22.00
# 50%           10645.0         0.60       1160.00       1360.00         25.00
# 75%           22759.5         0.73       1260.00       1450.00         28.00
# max          111322.0         1.00       1490.00       1580.00         34.00
#
#        act_total_75
# count        367.00
# mean          30.23
# std            2.91
# min           20.00
# 25%           28.00
# 50%           30.00
# 75%           32.00
# max           36.00

# %%
#2a: Dictionary Comprehension for State SAT Scores

data_dict = data.to_dict()
sd = {col_name: st_dev(data, col_name) for col_name in data.columns}
sd_df = (pd.DataFrame.from_dict(sd,orient = 'index')).rename(columns = {0:'Standard Dev.'})

#3: Trends (Which states have the highest and lowest total score?)
total_low = (state_sat.sort_values(by = "total", ascending = False)) # high (Minnesota)
total_high = (state_sat.sort_values(by = "total", ascending = True)) # low (West Virginia)

# Is there a state with a big difference between reading and math scores?
state_sat['difference_read_write'] = abs(state_sat['math']-state_sat['read_write'])
read_write_diff=state_sat.sort_values(by = "difference_read_write",ascending= False)
display(read_write_diff.head(10))
# Out:
#              state  participation_rate  read_write  math  total  \
# 9          Florida                1.00         516   483    999
# 0          Alabama                0.07         583   560   1143
# 3         Arkansas                0.06         582   559   1141
# 50   West Virginia                0.99         483   460    943
# 41  South Carolina                0.68         526   504   1030
# 24     Mississippi                0.03         628   608   1237
# 18       Louisiana                0.05         610   591   1200
# 10         Georgia                0.71         538   519   1058
# 36        Oklahoma                0.22         490   472    963
# 12           Idaho                1.00         505   488    993
#
#     difference_read_write
# 9                      33
# 0                      23
# 3                      23
# 50                     23
# 41                     22
# 24                     20
# 18                     19
# 10                     19
# ...

# %%
#1b: Summary Statistics for College_Sat dataset (SAT and ACT scores by College)
college_summary =round(college_sat.describe(),2)
display(college_summary)
# Out:
#        num_applicants  accept_rate  sat_total_25  sat_total_75  act_total_25  \
# count           367.0       367.00        364.00        367.00        367.00
# mean          16509.4         0.55       1175.77       1368.84         25.13
# std           16481.0         0.24        123.38        107.02          3.94
# min             211.0         0.04        793.00       1050.00         15.00
# 25%            4899.0         0.36       1080.00       1290.00         22.00
# 50%           10645.0         0.60       1160.00       1360.00         25.00
# 75%           22759.5         0.73       1260.00       1450.00         28.00
# max          111322.0         1.00       1490.00       1580.00         34.00
#
#        act_total_75
# count        367.00
# mean          30.23
# std            2.91
# min           20.00
# 25%           28.00
# 50%           30.00
# 75%           32.00
# max           36.00

# %%
#2b: Dictionary Comprehension for College SAT/ACT Score data
data_coll = college_sat.drop(columns=['school','test_optional','sat_total_interquart',
       'act_total_interquart'])
data_dict_coll = data_coll.to_dict()
sd_coll = {col_name: st_dev(data_coll, col_name) for col_name in data_coll.columns}
sd_df_coll = (pd.DataFrame.from_dict(sd_coll,orient = 'index')).rename(columns = {0:'Standard Dev.'})

#3: Trends (Which states have the highest and lowest highest interquartile SAT total score?)
total_high_coll_sat = (college_sat.sort_values(by = "sat_total_75", ascending = False)) # high (MIT)
total_low_coll_sat = (college_sat.sort_values(by = "sat_total_75", ascending = True)) # low (University El Paso)


# Which states have the highest and lowest highest interquartile SAT total score?)
total_high_coll_sat = (college_sat.sort_values(by = "act_total_75", ascending = False)) # high (MIT)
total_low_coll_act = (college_sat.sort_values(by = "act_total_75", ascending = True)) # low (Gallaudet University)

# %% [markdown]
# ### Explain Findings in Trend Analysis
#
# Within the State SAT dataset, two relationships were evaluated:
#
# * SAT Scores as a Factor of Participation Rate
# * Comparison of EBRW and Math scores
#
# Within the Participation Rate data, the expected trend was that higher participation rates would correlate with higher test scores. This was not the result. The perceived implication of higher test participation was that students would score higher if the state that they resided in provided more robust services relating to the tests. However, as participation rates increased, scores dropped. This relationship is well illustrated in the bar graph provided below entitled 'Participation Rate Color Overlay with SAT Scores by State'.
#
# Additionally the relationship between EBRW (Evidence Based Read-Write) and Math scores was evaluated. To determine this difference, the absolute value of the difference between the Math and EBRW score columns were inputted into a seperate column.
#
# In this column, the expected result was that some States would achieve better results on the Math or the EBRW portions of the exam. The observed difference between score categories was minimal and there is a correlation between reading scores and math scores [1]. Further analysis on related datasets would need to be completed to determine if a student's score on either section is related to their ability to take exams or their aptitude in the subject or math or reading/writing.
#
# Within the College SAT/ACT dataset, there is a clear trend in the score data that correlates with the acceptance rate of the institutions. That is to say, that more selective institutions can require applicants to have higher test scores, irrespective of alterior accolades that could be better indicators of the student's collegiate success.
#
# Additional discussion has been provided beneath each figure presented below.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#3a: Visualization of Data for SAT Scores by State

#Histogram of SAT scores
plt.hist(state_sat['total'],bins=10);
plt.xlabel('Total SAT Score')
plt.ylabel('Count')
plt.title('Fig 0:  Histogram of SAT Scores of US States');

# %% [markdown]
# ###### Fig 0: Analysis
#
# Figure 0 is histogram showing a count of the SAT scores of each state in the dataset. The data is nominally normally distributed, but is not ideal.

# %%
# SAT scores by state (bar graph)
plt.figure(figsize=(15,3));
plt.bar(total_low['state'],total_low['total']);
plt.xticks(rotation = 90);

#labels
plt.xlabel('State')
plt.ylabel('SAT Score')
plt.title('Fig 1: SAT Scores by State');

# %% [markdown]
# ###### Fig 1: Analysis
#
# Figure 1 is bar chart showing the SAT scores of each state in the dataset. This plot is a ancillary datapoint for future analysis within this report.

# %%
# Scatterplot of read/write and math

plt.scatter(state_sat['read_write'],state_sat['math']);
plt.xlabel('Evidence-Based Reading and Writing Score')
plt.ylabel('Math Score')
plt.title('Fig 2: Scatterplot of EBRW and Math SAT Scores');

# %% [markdown]
# ###### Fig 2: Analysis
#
# Figure 2 is scatterplot showing the score difference in EBRW and Math portions of the SAT exam. This plot shows that scores are roughly correlated.

# %%
# bar chart with color coded participation rate bars
state_sat = state_sat.sort_values(by = "total",ascending= False)

# bar chart
plt.figure(figsize=(15,3));
state_sat_bar = sns.barplot(x = state_sat['state'], y=state_sat['total']);
plt.xticks(rotation = 90);

#labels
plt.xlabel('State')
plt.ylabel('SAT Score')
plt.title('Fig 3: Participation Rate Color Overlay with SAT Scores by State')

#normalizing participation rate
part_max = state_sat['participation_rate'].max()
part_min = state_sat['participation_rate'].min()
norm = matplotlib.colors.Normalize(vmin=part_min, vmax=part_max)

#Color map (colorbar)
colors = plt.cm.cividis(norm(state_sat['participation_rate']))

#Setting the color of each bar
for i,bar in enumerate(state_sat_bar.containers[0]):
    bar.set_color(colors[i])

#legend
value = 1
mapped_value = norm(value)
color = plt.cm.Reds(mapped_value)
plt.xlim([-1,50])
plt.plot(0,0, marker='s', markersize=10, color= 'midnightblue', label=' Dark Blue Marks Low Participation')
plt.legend(loc='upper right')

#display plot
plt.show()

# %% [markdown]
# ###### Fig 3: Analysis
#
# Figure 3 is bar chart showing the SAT scores of each state in the dataset. A color overlay was applied to each bar to indicate the participate rate in the SAT exam for each student's college admissions process'.
#
# This plot shows a strong correlation between low participation rates and high scores.
#
# References: [10][11][12]

# %%
# bar chart with color coded bars representing the difference between math and reading/writing

#Setting up the data
state_sat['difference_read_write'] = abs(state_sat['math']-state_sat['read_write'])
read_write_diff=state_sat.sort_values(by = "difference_read_write",ascending= False)
state_sat = state_sat.sort_values(by = "total",ascending= False)

# bar chart
plt.figure(figsize=(15,3));
state_sat_bar = sns.barplot(x = state_sat['state'], y=state_sat['total']);
plt.xticks(rotation = 90);

#labels
plt.xlabel('State')
plt.ylabel('SAT Score')
plt.title('Fig 4: State SAT Overlayed with the Difference in EBRW & Math Scores')

#normalizing participation rate
part_max = state_sat['difference_read_write'].max()
part_min = state_sat['difference_read_write'].min()
norm = matplotlib.colors.Normalize(vmin=part_min, vmax=part_max)

#Color map (colorbar)
colors = plt.cm.cividis(norm(state_sat['difference_read_write']))

#Setting the color of each bar
for i,bar in enumerate(state_sat_bar.containers[0]):
    bar.set_color(colors[i])

#legend
value = 1
mapped_value = norm(value)
color = plt.cm.Reds(mapped_value)
plt.xlim([-1,50])
plt.plot(0,0, marker='s', markersize=10, color= 'midnightblue', label=' Smallest Difference in EBRW & Math Scores')
plt.legend(loc='upper right')

#display plot
plt.show()

# %% [markdown]
# ###### Fig 4: Analysis
#
# Figure 4 is bar chart showing the SAT scores of each state in the dataset. A color overlay was applied to each bar to indicate which states had a large difference between the EBRW and Math portions of the SAT exam.
#
# References: [10][11][12]

# %%
#3b: Visualization of Data for SAT Scores by College

#Histogram of SAT scores
sat_hist = plt.hist(college_sat['sat_total_25'], bins = 40)
plt.xlabel('SAT Score')
plt.ylabel('count')
plt.title('Fig 5: Histogram of SAT scores');
# Out:
# /Users/ryan/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/ryan/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# ###### Fig 5: Analysis
#
# Figure 5 is a histogram of the SAT scores. The data is relatively normally distributed, within reason. However it is right skewed, implying that students are less likely to receive the lowest score (800).

# %%
# Histogram of ACT scores
act_hist = plt.hist(college_sat['act_total_25'], bins = 20)
plt.xlabel('ACT Scores')
plt.ylabel('count')
plt.title('Fig 6: Histogram of ACT scores');

# %% [markdown]
# ###### Fig 6: Analysis
#
# Figure 6 is a histogram of the ACT scores. The data is normally distributed, within reason.

# %%
# Scatterplot of SAT and ACT/Accept Rate

#sat_accept_college_scatter = plt.scatter(college_sat['sat_total_25'],college_sat['accept_rate'])
#act_accept_college_scatter = plt.scatter(college_sat['act_total_25'],college_sat['accept_rate'])

fig, ax = plt.subplots()

# create first subplot with SAT scores on left y-axis
ax1 = ax.twinx()
ax1.scatter(college_sat['accept_rate'], college_sat['sat_total_25'], color='red', label='SAT Scores')
ax1.set_ylabel('SAT Scores')
ax1.set_ylim([0, 2000])

# create second subplot with ACT scores on right y-axis
ax2 = ax.twinx()
ax2.scatter(college_sat['accept_rate'], college_sat['act_total_25'], color='blue', label='ACT Scores')
ax2.set_ylabel('ACT Scores')
ax2.spines['right'].set_position(('axes', 1.2))
ax2.set_ylim([10, 55])

# set shared x-axis label
ax.set_xlabel('Acceptance Rate')

# show legend
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.title('Fig 7: Relationship between Test Scores and Accept. Rate')
plt.show()

# %% [markdown]
# ###### Fig 7: Analysis
#
# Figure 7 plots the SAT and ACT scores vs acceptance rate for each school in the dataset. Red dots represent the SAT scores, blue dots represent the ACT scores.
#
# This plot was intended to determine if a student would have an admissions advantage if they took one over the other. The scatterplot shows a reasonable correlation between both exams and students should expect the same admissions treatment if either exam is requested.
#
# References: [10][11][12]

# %%
# Masking the data: If test is mandatory, does that change the acceptance rate?

mask_yes = college_sat['test_optional'] == 'Yes'
mask_no = college_sat['test_optional'] == 'No'

sorted_yes_college_sat = college_sat[mask_yes]
sorted_no_college_sat = college_sat[mask_no]
#display(sorted_yes_college_sat)
#display(sorted_no_college_sat)


# Scatterplot showing how mandatory tests affect number of applicants/ acceptance rate
fig, ax = plt.subplots()
ax.scatter(sorted_yes_college_sat['accept_rate'], sorted_yes_college_sat['sat_total_25'], color='red')
ax.scatter(sorted_no_college_sat['accept_rate'], sorted_no_college_sat['sat_total_25'], color='blue')

ax.set_xlim([0, 1])
ax.set_ylim([250, 2000])
plt.title('Fig 8: Mandatory SAT Policies and SAT Scores')
plt.ylabel('SAT Scores')
plt.xlabel('Acceptance Rate')

plt.show()

# %% [markdown]
# ###### Fig 8: Analysis
#
# Figure 8 plots the SAT score vs acceptance rate for each school in the dataset. Red dots represent the schools with SAT policies, blue indicates the school did not require the SAT score to be submitted as part of their admissions process.
#
# The scatterplot shows a reasonable correlation between both the 'No policy' and 'SAT included' schools, however there was not a large enough 'No Policy' data pool of data to draw sufficient conclusions.
#
# References: [10][11][12]

# %%
#Setting up the data

# bar chart
college_sat = college_sat.sort_values('num_applicants', ascending = False)
plt.figure(figsize=(150,5));
college_sat_bar = sns.barplot(x = college_sat['school'], y=college_sat['num_applicants']);
plt.xticks(rotation = 90);

#labels
plt.xlabel('School')
plt.ylabel('Number of Applicants')
plt.title('Fig 9: Participation Rate Color Overlay with SAT Scores by State')

#normalizing participation rate
part_max = college_sat['sat_total_75'].max()
part_min = college_sat['sat_total_75'].min()
norm = matplotlib.colors.Normalize(vmin=part_min, vmax=part_max)

#Color map (colorbar)
colors = plt.cm.cividis(norm(college_sat['sat_total_75']))

#Setting the color of each bar
for i,bar in enumerate(college_sat_bar.containers[0]):
    bar.set_color(colors[i])

#legend
value = 1
mapped_value = norm(value)
color = plt.cm.Reds(mapped_value)
plt.xlim([-3,368])
plt.plot(0,360, marker='s', markersize=10, color= 'midnightblue', label='Fig 9: Total Applicant Num. Overlayed with SAT Scores by School')

#display plot
plt.show()

# %% [markdown]
# ###### Fig 9: Analysis
#
# Figure 9 plots the total number of applicants each school received in 2021. A color mask is then applied to each bar to show the upper interquartile SAT score for each school.
#
# Schools with the highest upper interquartile SAT scores are indicated by the yellow bars and applicants with the lowest scores are indicated by dark blue bars.
#
# The top schools receive a large number of applications and maintain a high interquartile SAT score amoungst each cohort.
#
# References: [10][11][12]

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# The ongoing usefulness of the SAT and ACT standardized tests as a predictor of college success is a matter of ongoing debate. The purpose of this analysis was to investigate the results of standardized testing and evaluate the relationship between collegiate standardized testing and success in college admissions.
#
# The relationship between success on standardized tests, such as the ACT and SAT, and successful admission to top US Universities is clearly defined within the data. More prestigious institutions with lower acceptance rates accept students with higher total test scores and less pretigious institutions have a relative lower threshold for acceptance [fig. 6].
#
# However, as SAT/ACT participation rate increases, the average score decreases noticably [fig. 3]. Further analysis would be required to determine the cause of this trend. Without further analysis, this trend would imply that the efficacy of the test to determine a  student's fitness for higher education would seem to be influenced by other factors outside of the student's aptitude.
#
# In recent years, the trend of colleges requiring standardized test scores such as the SAT and ACT has shifted towards becoming less strict. According to a report [1], in Fall 2021, only 54% of colleges in the US required the SAT and 57% required the ACT, which is down from previous years. The "test optional" approach has become the new normal in college admissions [2], allowing students to apply without having to submit their test scores. There is a growing list of colleges that no longer require all SAT scores [1], giving students more flexibility in the college application process.
#
#
# The findings of this analysis suggest that the SAT and ACT exams may provide beneficial data to help predict a student's success, they should not be relied upon as the sole indicator of a student's potential for success in college. While these exams can provide valuable information, they should be considered as one part of a larger picture.

# %%
+
